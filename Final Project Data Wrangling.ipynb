# %%
import pandas as pd
import numpy as np

# %%
Url='https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %% [markdown]
# ### Q1

# %%
df=pd.read_csv(Url)
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### Q2

# %%
#a
print('No.of rows : ',df.shape[0])
print('No.of columns : ',df.shape[1])
# Out:
# No.of rows :  57394
# No.of columns :  49

# %%
#b
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
#c
print(df.info(),'\n\n\n')
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %% [markdown]
# ### Q3

# %%
# a
df['location'].nunique()
# Out:
# 216

# %%
# b
df['continent'].value_counts().head(1)
# Out:
# Europe    14828
# Name: continent, dtype: int64

# %%
# c
print('The maximum value : ',df['total_cases'].max())
print('The mean value : ',df['total_cases'].mean())
# Out:
# The maximum value :  55154651.0
# The mean value :  167797.3688753302

# %%
# d
print("25% of death is : ",df['total_deaths'].describe()['25%'])
print("50% of death is : ",df['total_deaths'].describe()['50%'])
print("75% of death is : ",df['total_deaths'].describe()['75%'])
# Out:
# 25% of death is :  13.0
# 50% of death is :  84.0
# 75% of death is :  727.0

# %%
# e

df['continent'][df['human_development_index']==df['human_development_index'].max()]
# Out:
# 38632    Europe
# 38633    Europe
# 38634    Europe
# 38635    Europe
# 38636    Europe
#           ...
# 38950    Europe
# 38951    Europe
# 38952    Europe
# 38953    Europe
# 38954    Europe
# Name: continent, Length: 323, dtype: object

# %%
# f
df['continent'][df['gdp_per_capita']==df['gdp_per_capita'].min()]
# Out:
# 10259    Africa
# 10260    Africa
# 10261    Africa
# 10262    Africa
# 10263    Africa
#           ...
# 10501    Africa
# 10502    Africa
# 10503    Africa
# 10504    Africa
# 10505    Africa
# Name: continent, Length: 247, dtype: object

# %% [markdown]
# ### Q4

# %%
# a
df=df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ### Q5

# %%
# a
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_18872/3823015040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
#b

df.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
#c
df1=df.copy()
df1.dropna(subset=['continent'],inplace=True)
df1
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
#d

df1.fillna(0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# continent                  0
# location                   0
# date                       0
# total_cases                0
# total_deaths               0
# gdp_per_capita             0
# human_development_index    0
# dtype: int64

# %% [markdown]
# ### Q6

# %%
#a
df1['date']=pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# continent                          object
# location                           object
# date                       datetime64[ns]
# total_cases                       float64
# total_deaths                      float64
# gdp_per_capita                    float64
# human_development_index           float64
# dtype: object

# %%
#b
df1.date.dt.month
# Out:
# 0        12
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 56743    11
# 56744    11
# 56745    11
# 56746    11
# 56747    11
# Name: date, Length: 56748, dtype: int64

# %% [markdown]
# ### Q7

# %%
#a
df1.groupby('continent')
df1.reset_index().max()
df1.max()
# Out:
# continent                        South America
# location                              Zimbabwe
# date                       2020-12-11 00:00:00
# total_cases                         11205486.0
# total_deaths                          247220.0
# gdp_per_capita                        116935.6
# human_development_index                  0.953
# dtype: object

# %%
#b
df_groupby=df1.max()
df_groupby
# Out:
# continent                        South America
# location                              Zimbabwe
# date                       2020-12-11 00:00:00
# total_cases                         11205486.0
# total_deaths                          247220.0
# gdp_per_capita                        116935.6
# human_development_index                  0.953
# dtype: object

# %% [markdown]
# #### Q8

# %%
df.head()
# Out:
#   continent     location      date  total_cases  total_deaths  gdp_per_capita  \
# 0      Asia  Afghanistan  31/12/19          NaN           NaN        1803.987
# 1      Asia  Afghanistan  01/01/20          NaN           NaN        1803.987
# 2      Asia  Afghanistan  02/01/20          NaN           NaN        1803.987
# 3      Asia  Afghanistan  03/01/20          NaN           NaN        1803.987
# 4      Asia  Afghanistan  04/01/20          NaN           NaN        1803.987
#
#    human_development_index
# 0                    0.498
# 1                    0.498
# 2                    0.498
# 3                    0.498
# 4                    0.498

# %%
df['total_deaths_to_total_case']=df['total_deaths']/df['total_cases']
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_18872/4143541327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_deaths_to_total_case']=df['total_deaths']/df['total_cases']

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index  total_deaths_to_total_case
# 0            1803.987                    0.498                         NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Q9

# %%
#a
sns.histplot(df['gdp_per_capita'])
# Out:
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Count'>

# %%
#b
plt.scatter(x=df['total_cases'],y=df['gdp_per_capita'])
plt.xlabel('total_cases')
plt.ylabel('gdp_per_capita')
# Out:
# Text(0, 0.5, 'gdp_per_capita')

# %%
#c
sns.pairplot(df_groupby)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18872/4211100802.py in <module>
#       1 #c
# ----> 2 sns.pairplot(df_groupby)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# ...

# %%
#d 
sns.barplot(df['continent'],df['total_cases'])
# Out:
# C:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='continent', ylabel='total_cases'>

# %% [markdown]
# #### Q10

# %%
df_groupby.to_csv('groupby.csv')
